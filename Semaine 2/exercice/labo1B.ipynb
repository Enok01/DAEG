# %% [markdown]
# # Laboratoire 1B
# ## Exercice 1
# Créer un algo qui permette d’afficher les étoiles selon le format suivant :
# ![image.png](data:image/png;base64,...)

# %%
#Solution
for i in range(1,12):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********

# %% [markdown]
# ## Exercice2
# Créer un algo qui respecte les consignes suivantes:
# - Demander à l’utilisateur la valeur de départ.
# - Demander à l’utilisateur la valeur de fin.
# - Demander à l’utilisateur la valeur d’incrémentation.
# - Afficher à l’écran les valeurs à partir de la valeur de début jusqu’à la valeur de fin selon l’incrémentation.
#
# **Exemple 1:**
# - Quelle est la valeur de départ? 2
# - Quelle est la valeur de fin? 15
# - Quel est l’incrémentation? 3
#
# 2 5 8 11 14
#
# **Exemple 2:**
# - Quelle est la valeur de départ? 20
# - Quelle est la valeur de fin? -5
# - Quel est l’incrémentation? -5
#
# 20 15 10 5 0 -5

# %% [markdown]
# ## Exercice 3 Trouver les nombres parfaits
#
# Un nombre parfait est un nombre entier positif qui est égal à la somme de ses diviseurs propres.
#
# Par exemple, 6 est un nombre parfait car ses diviseurs propres sont 1, 2, et 3, et 1 + 2 + 3 = 6.
#
# Écrivez un programme qui affiche les nombres parfaits de 2 jusqu'à 1000. Inutile de créer des listes ou autre tableau

# %% [markdown]
# ## Exercice 4 : Jeu de "trouve le nombre"
# Créez un jeu où l'ordinateur choisit un nombre aléatoire entre 1 et 100, et l'utilisateur doit deviner ce nombre.
#
# Utilisez des boucles pour permettre à l'utilisateur de faire plusieurs tentatives et donner des indices (par exemple, "trop bas" ou "trop haut").
#
# Générez un nombre aléatoire avec
# <code>
# import random
# nombre_a_deviner = random.randint(1, 100)</code>

# %% [markdown]
# ## Exercice 5: Fonction de purge
# Ecrivez une fonction qui purge une chaîne d'un caractère, la chaîne comme le caractère étant passés en argument. Si
# le caractère spécifié ne fait pas partie de la chaîne, celle-ci devra être retournée intacte.
#
# Par exemple :
# - Purge("Bonjour","o") renverra "Bnjur"
# - Purge("J'ai horreur des espaces"," ") renverra "J'aihorreurdesespaces"
# - Purge("Moi, ca ne change rien", "y") renverra "Moi, ca ne change rien"
#
# Testez votre fonction
# **première version avec une boucle sur chaque lettre** de la chaine de caractère

# %% [markdown]
# **Seconde version en utilisant la fonction [replace](https://www.w3schools.com/python/ref_string_replace.asp)**

# %% [markdown]
# ## Exercice 6 : Evolution de purge
# Surchargez la méthode précédente pour faire une version dans laquelle vous ne passez plus un seul caractère, mais une string.
#
# Utilisez les méthodes [find](https://www.w3schools.com/python/ref_string_find.asp) pour trouver la position de la sous-chaîne à supprimer dans la chaîne, et récupérez la taille d'une string avec [len](https://www.w3schools.com/python/ref_func_len.asp) .

# %% [markdown]
# ## Exercice 7 : Sauvegarder une suite de Fibonacci dans un fichier
#
# Écris une fonction nommée sauvegarder_suite_Fibonacci(limite) qui :
#
# * Prend en paramètre un entier positif limite ;
# * Génère la suite de Fibonacci (0, 1, 1, 2, 3, 5, 8, 13, ...) jusqu’à ce que le prochain terme dépasse limite ;
# * Enregistre tous les termes inférieurs ou égaux à limite dans un fichier texte nommé suite_fibonacci.txt, un nombre par ligne.
#
# Faire une seconde fonction lire_Fibonnacci() qui affichera le contenu du fichier que vous venez de créer
#
# ### Rappel : Qu’est-ce que la suite de Fibonacci ?
#
# C’est une suite de nombres où chaque terme est la somme des deux précédents, avec :
#
# * F(0) = 0
# * F(1) = 1
# * F(n) = F(n-1) + F(n-2)
